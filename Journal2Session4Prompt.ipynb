# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.exponential(1.0, 1000)

plt.hist(x, bins=100)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.savefig('exponential_histogram.pdf')
plt.show()
